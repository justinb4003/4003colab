# %% [markdown]
# <a href="https://colab.research.google.com/github/justinb4003/4003colab/blob/main/Intro_Season204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction
#
# Python started out, under the name ABC, as an easy language for people to learn. That was over 30 years ago now, and it has grown well beyond just a teaching language but still remains strong as a great language to start in.
#
# We'll start working our way through this notebook to become aquainted with some of the basic elements of Python programming.
#
# We'll start by using the ```print()``` function. Click the play button next to the cell to execute it.
#
# The first time you execute this it might take a while to run. Behind the scenes Google is allocating you a virtual machine (VM) for you to use. It'll only take a minute or so usuallly and then you'll have about 12GB (gigabytes) of RAM and a couple of server grade CPUs to work with.

# %%
print('hello world!')
# Out:
# hello world!

# %% [markdown]
# If we wanted to print the statement twice we could just copy and paste it. The code will execute line-by-line from top to bottom; until we start working with loops and functions.
#
# For now go ahead and use the above block to copy-paste the command so it repeats and run it again. You should see the output change when you click the play arrow again.
#
# Not surprisingly there's a better way to repeat an action like this in programming and that is where loops and functions come in.
#
# Let's start with a loop that prints something 5 times.

# %%
for x in range(5):
    print('hello')
# Out:
# hello
# hello
# hello
# hello
# hello

# %% [markdown]
# What we've done there is create a ```for``` loop that iterates over the values returned by the ```range()``` function which generates a list of values ```0-4```. Let's use a similar block of code to see the value of ```x``` too.

# %%
for x in range(5):
    print(x)
    print('hello')
# Out:
# 0
# hello
# 1
# hello
# 2
# hello
# 3
# hello
# 4
# hello

# %% [markdown]
# You might hae expected that result in the numbesr 1-5, the way you would count them, but programmers and programming languages have this thing where we start counting at zero. There are reasons for this but it is best to just accept it for now and move on.
#
# In that vein of thought, if you're noticed that your code is magically getting colors applied to it that's just a feature of the editor. There's visual aids to help us identity what's what in programming. Different color schemes in Colab can be found under Tools -> Settings -> Editor -> Editor colorization.
#
# And next we'll move to whitespace. The stuff you don't see.
#
# ## Whitespace
#
# Whitespace is the catchall term for punctuation marks that don't usually make a symbol on the screen. You can think of them as keystrokes on a typewriter that result in white space on a white piece of paper. More specifically, the spacebar, tab, and enter key.
#
# There's a few things to note before we get started.
#
# If you've seen any programming before the idea that we indent code to show what layer they're in is likely familiar. However, most other languages only treat that as a convention rather than a rule. Instead, the rules there are likely using punctuation like ```{``` and ```}``` to denote the beginning and end of blocks. Others might use ```begin``` or ```end``` and then you get the cutesy conventions used in the POSIX shell like ```if``` and ```fi``` or ```case``` being terminated with ```esac```.
#
# If you haven't been exposed to this much before you can see it above in the ```for``` loop that we made. The first statement begins the loop and everything that weant to run 'inside' it must be indented. Because keeping things lined up is important we always (at least by default) use monospace fonts in code editors. A monospace font is one where all of the letters and symbols take up the same amount of space. The font you're reading this in is not monospace so 'WWW' is wider than 'lll' but in the programming editor they will be.
#
# Let's experiment with some different ways of showing how indentation level affects things.
#
# First, let's add a print statement to end of our codep to indicate we're done.

# %%
for x in range(5):
    print(x)
    print('hello')
print('done!')
# Out:
# 0
# hello
# 1
# hello
# 2
# hello
# 3
# hello
# 4
# hello
# done!

# %% [markdown]
# Now we see the numbers and 'hello' print out 5 times and then we see 'done!' at the end. Let's change the indentation of the line that prints 'hello' out.  Can  you guess what this change will result in?

# %%
for x in range(5):
    print(x)
print('hello')
print('done!')
# Out:
# 0
# 1
# 2
# 3
# 4
# hello
# done!

# %% [markdown]
# The 'hello' now prints "outside" of the loop, after it has completed, not during it. That's what makes the spacing so important, and this gets used everywhere. It might seem tedious at first glance, but text editors meant for programming almost always have ways of lining things up for you or shifting them around as instructed.
#
# Generally speaking the editor will place you where you should be each time you start a new line and ```[TAB]``` will move you in one level and ```[SHIFT]+[TAB]``` will move you out one level.
#
# Rather than dive deep into the details of what can or should be done with indentation, a larger subject than you probably think necessary, we'll move over to functions and how to create our own and start working with them.

# %% [markdown]
# ## Functions
#
# Functions in programming borrow a lot from the notion of functions in algebra, a subject you're likely somewhat familar with, so let's look at implementing the mathematical function $f(x)=2x+4$.
#
# Here we have a formula, which takes the variable $x$ which is then "plugged in" to the equation and the result is returned.
#
# In Python we use the ```def``` keyword to denote that we're going to define a function here. Next we see the function's name which is ```f``` and then in the parenthesis we give names to the variable parameters that our function will take.

# %%
def f(x):
    print('Running calculation...')
    y = 2*x+4
    return y

print('donezo!')
# Out:
# donezo!

# %% [markdown]
# When run the only output you see is 'donezo!' and the 'Running calculation...' never appears. That's beause when we define a function we're asking the program to save this block of instructions and let us call it by name later on. In mathematics functions and variables are usually only one letter or symbol, maybe with a subscript, but in programming we can name things a bit more explicity.
#
# How one should actually name things is another topic that probably seems too long for something simple. It will come up later and there really is no concrete answer on how to do that. Frequently it just depends on the group and what works for everybody involved.
#
# We'll look at how to call our function next, and again this may look a bit like something you've seen in math class. If we wanted to know the value of the function $f(x)=2x+4$ when $x=0$ we would evaluate $f(0)$ and in Python it looks like the next cell. Go ahead and excute it.

# %%
f(0)
# Out:
# Running calculation...
# 4

# %% [markdown]
# There! Now we see our 'Running calculation...' text output and the number 4, the result of $2x+4$ when $x=0$. The 4 appears because that was returned by ```f(0)``` and our cells will display whatever the last command returns to us. It's a nice feature of notebook development that makes debugging a bit easier.
#
# But we usually want to store our calculation somewhere, and that brings us to variables.
#
# ## Variables
#
# It is best to start here once again borrowing from algebra where we give names to our numbers. In programming we tend to use more than just a single letter for those names. But, when discussing simple examples like we have so far we've just kept them to single letters to make the transition from algebraic thinking to this. That will slowly chnage as we introduce variables that are doing more than just holding a number for us.
#
# The ins and outs of how they work is an exhausting topic so we'll just ease into it slowly learning what we need to know as we go. You've already seen them in action so some of this might seem repetative.
#
# If you're coming at this tutorial from a language like Java, C++, C, C#, TypeScript, or... many others you may be thrown off a bit by no mention of types. Python is in the minority of popular languages in that typing of variables isn't required. This has positives and negatives and we'll explore them later. However, to put your mind at ease we'll mention that the technical term for what it does is called 'duck-typing' as in 'if it walks and talks like a duck.' If something walks like an integer and talks like an integer then it's probably an integer. Yes, that's the technical term. The language _is_ named after Monty Python.

# %%
# First we'lll redefine the 'f' function so we don't have the print() call
# there anymore
def f(x):
    y = 2*x+4
    return y


# We can assign a value to a fixed value like this
x = 0
# And then use it just as we would the number itself.
f(x)
# Out:
# 4

# %%
# We can store our calculation's value for later too
start_value = f(0)
mid_value = f(5)
end_value = f(10)
print(start_value)
# Out:
# 4

# %% [markdown]
# One thing that is very different than anything in algebra is that our variables have a limited lifetime, or area of the program where they exist. The short answer to this is a variable exists in function it was created in. If the variable is created at the file (or module) level it exists everywhere in the file, including in the functions, but only as a read-only variable. If you try and assign to it it will create new variable that masks the outer one.
#
# In a notebook we can consider this one file or module. The scoping, the technical term for the topic at hand, works the same.
#
# Let's try some simple examples.

# %%
msg = 'File/module level message'

# pring the msg variable
def p():
    print(msg)

p()
# Now inspect the value of msg at the module level
msg
# Out:
# File/module level message
# 'File/module level message'

# %% [markdown]
# The above demonstrated using a module level variable as a read-only version.

# %%
# Now with a slight twist
msg = 'File/module level message'

# pring the msg variable
def p():
    msg = 'Function level message'
    print(msg)

p()
msg
# Out:
# Function level message
# 'File/module level message'

# %% [markdown]
# Above we see that we can reassign ```msg``` to mean something else in ```p()``` and when the cell ends the value of ```msg``` remains what it was at the top.

# %%
# Now with a slight twist
msg = 'File/module level message'

# pring the msg variable
def p():
    # We pull in the 'global' or module/file level msg variable
    global msg
    msg = 'Function level message'
    print(msg)

p()
msg
# Out:
# Function level message
# 'Function level message'

# %% [markdown]
# Above we see the ```global``` keyword introduced which you should basically never use. However, I wanted to make sure you knew it was possible to do something like this. When you think you __need__ to there's almost always a better way.
#
# ### What about the public and private stuff?
#
# Unlike many other language (Java, C#, C++, etc) Python doesn't have protection levels on variables. You sometimes see things like private, protected, public, friend, or other as 'decorators' on a variable declartion in those languages.
#
# Not only does Python not require declaring variables but there are no protection levels either. Instead we use a polite suggestion technique in how we name variables.
#
# If you expect somebody else to use your variable in a different module you name it normally. If you think people probably shouldn't touch a certain variable but they might want to preface it with a single underscore (```_```) to make them think twice. If you think somebody would wreck everything if they touched something you name it with two underscores (```__```). We apply this same convention to functions within classes and modules too.
#
# Because "underscore" and "double undscore" are hard to say repeatedly the shortened versions are 'under' and 'dunder'. So if you had a variable named ```__x``` you would calll it 'dunder x'.

# %%
# Whitespace matters in Python!
def hello2():
    print('hello again!')
    print('and again!')
hello2()

# %%
def hello3():
    print('hello again!')
print('and again!')
hello3()

# %%
# Now, functions usually return something, like a calculation or operations on some data
def pythag(a, b):
    from math import sqrt
    c = sqrt(a**2 + b**2)
    return c

pythag(3, 4)

# %%
pythag(6, 7)

# %%
# Secret key
sk = '4003data'
# Event key
ek = '2023micmp4'

url = f'https://trisonics-scouting-api.azurewebsites.net/api/GetResults?secret_team_key={sk}&event_key={ek}'
url
# Out:
# 'https://trisonics-scouting-api.azurewebsites.net/api/GetResults?secret_team_key=4003data&event_key=2023micmp4'

# %% [markdown]
# We'll import the ```requests``` library here to pull data from our HTTP
# API that lives in Azure. This is almost exactly what your web browser
# is doing to retrieve a web page but in this case we're just pulling back data that wouldn't render in a browser except as raw JSON structured data.

# %%
import requests

resp = requests.get(url)

# %%
# The above cell lets us see that we've got a response object of some kind
# but we don't know the properties of it. The 'help' command can
# inspect it and, if properly documented internallly, will tell us how to
# use it.
help(resp)
# Out:
# Help on Response in module requests.models object:
#
# class Response(builtins.object)
#  |  The :class:`Response <Response>` object, which contains a
#  |  server's response to an HTTP request.
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, *args)
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Allows you to use a response as an iterator.
#  |
#  |  __nonzero__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
# ...

# %%
resp.text
# Out:
# '[{"scouter_name":"Casey scott","secret_team_key":"4003data","event_key":"2023micmp4","match_key":1,"scouting_team":910,"auto_nothing":0,"auto_engaged":0,"auto_docked":0,"auto_community":1,"endgame_nothing":0,"endgame_dead_robot":0,"endgame_engaged":1,"endgame_docked":0,"endgame_parked":0,"auto_cubes_high":0,"auto_cubes_medium":0,"auto_cubes_low":0,"auto_cones_high":1,"auto_cones_medium":0,"auto_cones_low":0,"teleop_cubes_high":1,"teleop_cubes_medium":0,"teleop_cubes_low":0,"teleop_cones_high":1,"teleop_cones_medium":1,"teleop_cones_low":1,"match_notes":"Fast and accurate with a semi reliable intake"},{"scouter_name":"Sarah","secret_team_key":"4003data","event_key":"2023micmp4","match_key":1,"scouting_team":7197,"auto_nothing":0,"auto_engaged":0,"auto_docked":0,"auto_community":1,"endgame_nothing":0,"endgame_dead_robot":0,"endgame_engaged":1,"endgame_docked":0,"endgame_parked":0,"auto_cubes_high":1,"auto_cubes_medium":0,"auto_cubes_low":1,"auto_cones_high":0,"auto_cones_medium":0,"au
# ...

# %%
resp.json()
# Out:
# [{'scouter_name': 'Casey scott',
#   'secret_team_key': '4003data',
#   'event_key': '2023micmp4',
#   'match_key': 1,
#   'scouting_team': 910,
#   'auto_nothing': 0,
#   'auto_engaged': 0,
#   'auto_docked': 0,
#   'auto_community': 1,
#   'endgame_nothing': 0,
#   'endgame_dead_robot': 0,
#   'endgame_engaged': 1,
#   'endgame_docked': 0,
#   'endgame_parked': 0,
#   'auto_cubes_high': 0,
#   'auto_cubes_medium': 0,
#   'auto_cubes_low': 0,
#   'auto_cones_high': 1,
#   'auto_cones_medium': 0,
#   'auto_cones_low': 0,
#   'teleop_cubes_high': 1,
#   'teleop_cubes_medium': 0,
#   'teleop_cubes_low': 0,
#   'teleop_cones_high': 1,
#   'teleop_cones_medium': 1,
#   'teleop_cones_low': 1,
#   'match_notes': 'Fast and accurate with a semi reliable intake'},
#  {'scouter_name': 'Sarah',
#   'secret_team_key': '4003data',
#   'event_key': '2023micmp4',
#   'match_key': 1,
#   'scouting_team': 7197,
#   'auto_nothing': 0,
#   'auto_engaged': 0,
#   'auto_docked': 0,
# ...

# %%
obj = resp.json()


# Each record in the list is a match, so let us iterate over them and print one
# by one.
for m in obj:
    print(m)
# Out:
# {'scouter_name': 'Casey scott', 'secret_team_key': '4003data', 'event_key': '2023micmp4', 'match_key': 1, 'scouting_team': 910, 'auto_nothing': 0, 'auto_engaged': 0, 'auto_docked': 0, 'auto_community': 1, 'endgame_nothing': 0, 'endgame_dead_robot': 0, 'endgame_engaged': 1, 'endgame_docked': 0, 'endgame_parked': 0, 'auto_cubes_high': 0, 'auto_cubes_medium': 0, 'auto_cubes_low': 0, 'auto_cones_high': 1, 'auto_cones_medium': 0, 'auto_cones_low': 0, 'teleop_cubes_high': 1, 'teleop_cubes_medium': 0, 'teleop_cubes_low': 0, 'teleop_cones_high': 1, 'teleop_cones_medium': 1, 'teleop_cones_low': 1, 'match_notes': 'Fast and accurate with a semi reliable intake'}
# ...

# %%
# We can also iterate through and only print out certain elements
for m in obj:
    if m['scouter_name'] == 'Gavin Thomsen':
        print(m)

# %%
# Now grab everything that we scouted when watching team 74
for m in obj:
    if m['???'] == 74:
        print(m)

# %%
# Now let's find the average number of high cubes or cones scored by the
# team during tele-op

total = 0
for m in obj:
    if m['???'] == 74:
        total += m['teleop_cones_high']
        total += m['teleop_cubes_high']
print(total)

# %% [markdown]
# Now let's make an example where we do that for every time. We want the high cone and cube total for every team in that event.
#
# With that we already know this isn't much of a stretch to get there.

# %%
all_teams =  [m['scouting_team'] for m in obj]
sorted(all_teams)

# %%
teams = set(all_teams)
teams

# %%
for t in teams:
    total = 0
    for m in obj:
        if m['scouting_team'] == t:
            total += m['teleop_cones_high']
            total += m['teleop_cubes_high']
    print(f'Team {t} got {total}')

# %% [markdown]
# Ok, that works, but we're programmers and we're lazy. That seems like
# something we'll end up doing a lot of, and so will a lot of other people so maybe there's a good way of dealing wit this.
#
# And there is. Dataframes. Dataframes are like spreadsheets for programmers

# %%
import pandas as pd

df = pd.DataFrame(data=obj)
# Run this cell with the .reset_index() call and without. Do you notice the
# way the table formats a bit differently? This is to "flatten" the data out
# after our group by
gropued_df = df.groupby('scouting_team').sum(numeric_only=True).reset_index()
# gropued_df = df.groupby('scouting_team').sum(numeric_only=True)
gropued_df['teleop_high'] = gropued_df['teleop_cones_high'] +  gropued_df['teleop_cubes_high']
gropued_df.head()
# Out:
#    scouting_team  match_key  auto_nothing  auto_engaged  auto_docked  \
# 0             51        274             0             0            0
# 1             70        341             0             2            0
# 2             74        366             0             0            0
# 3            107       9517             2             3            1
# 4            226        247             0             2            3
#
#    auto_community  endgame_nothing  endgame_dead_robot  endgame_engaged  \
# 0               9                0                   0                7
# 1               9                0                   0                7
# 2               9                0                   0               10
# 3               5                0                   2                5
# 4               8                0                   0                6
#
#    endgame_docked  ...  auto_cones_high  auto_cones_medium  auto_cones_low  \
# ...
